# %% [markdown]
# # Assignment 01 - Predict Price of Diamonds
# This is the first assignment of the UNICAMP lecture MO444-Machine Learning and Pattern Recognition
#
# ## Objective
# Explore linear  regression alternatives  and  come  up  with  the  best  possible  model  to  the  problems,  avoiding overfitting. In particular, predict the price of diamonds from their attributes (e.g., depth, clarity, color) using the Diamonds dataset (https://www.kaggle.com/shivam2503/diamonds).

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
pd.options.display.float_format = '{:.2f}'.format
from sklearn import preprocessing, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Load the Diamonds Dataset
# - Load
# - Check its structure and integrity

# %%
train_and_validation_dataset = pd.read_csv('diamonds-dataset/diamonds-train.csv')
display(train_and_validation_dataset.info())
display(train_and_validation_dataset.head(5))

test_dataset = pd.read_csv('diamonds-dataset/diamonds-test.csv')
display(test_dataset.info())
display(test_dataset.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45849 entries, 0 to 45848
# Data columns (total 10 columns):
# carat      45849 non-null float64
# cut        45849 non-null object
# color      45849 non-null object
# clarity    45849 non-null object
# x          45849 non-null float64
# y          45849 non-null float64
# z          45849 non-null float64
# depth      45849 non-null float64
# table      45849 non-null float64
# price      45849 non-null int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.5+ MB
# None
#    carat        cut color clarity    x    y    z  depth  table  price
# 0   1.62      Ideal     I     VS2 7.53 7.58 4.69  62.10  55.00  10501
# 1   0.30    Premium     G     SI1 4.39 4.35 2.57  58.80  60.00    574
# 2   1.37      Ideal     F     VS1 7.28 7.22 4.32  59.60  57.00  11649
# 3   0.33       Fair     H    VVS2 4.40 4.32 2.84  65.10  59.00    922
# 4   0.32  Very Good     F     VS2 4.43 4.48 2.62  58.80  62.00    602
# ...

# %% [markdown]
# ### Preprocess Dataset
# There are 9 attributes as follows:
# - carat:  weight of the diamond (0.2–5.01)
# - cut:  quality of the cut (Fair, Good, Very Good,Premium, Ideal)
# - color:  diamond color, from J (worst) to D (best)
# - clarity:  a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1,
# IF (best))
# - x:  length in mm (0–10.74)
# - y:  width in mm (0–58.9)
# - z:  depth in mm (0–31.8)
# - depth:  total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43–79)
# - table:  width of top of diamond relative to widest point (43–95)
# - price:  price in US dollars
#
# First, we need to transform properties "cut", "color" and "clarity" into usable features.

# %%
#lmplot(x=train_and_validation_dataset['cut'],y=train_and_validation_dataset['price'])
sns.lmplot(x="cut", y="price", col="train_and_validation_dataset", data=train_and_validation_dataset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-a30c9148f511> in <module>()
#       1 #lmplot(x=train_and_validation_dataset['cut'],y=train_and_validation_dataset['price'])
# ----> 2 sns.lmplot(x="cut", y="price", col="train_and_validation_dataset", data=train_and_validation_dataset)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     550     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     551     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 552     data = data[cols]
# ...

# %%
def preprocessDataset(dataset):
    dataset = dataset.copy() # avoid false positive of "A value is trying to be set on a copy of a slice from a DataFrame"
    dataset.cut.replace('Fair', 1, inplace=True)
    dataset.cut.replace('Good', 2, inplace=True)
    dataset.cut.replace('Very Good', 4, inplace=True)
    dataset.cut.replace('Premium', 7, inplace=True)
    dataset.cut.replace('Ideal', 11, inplace=True)

    dataset.color.replace('D', 7, inplace=True)
    dataset.color.replace('E', 6, inplace=True)
    dataset.color.replace('F', 5, inplace=True)
    dataset.color.replace('G', 4, inplace=True)
    dataset.color.replace('H', 3, inplace=True)
    dataset.color.replace('I', 2, inplace=True)
    dataset.color.replace('J', 1, inplace=True)

    dataset.clarity.replace('I1', 1, inplace=True)
    dataset.clarity.replace('SI2', 2, inplace=True)
    dataset.clarity.replace('SI1', 3, inplace=True)
    dataset.clarity.replace('VS2', 4, inplace=True)
    dataset.clarity.replace('VS1', 5, inplace=True)
    dataset.clarity.replace('VVS2', 6, inplace=True)
    dataset.clarity.replace('VVS1', 7, inplace=True)
    dataset.clarity.replace('IF', 8, inplace=True)
    
    return dataset

preprocessed_train_and_validation_dataset = preprocessDataset(train_and_validation_dataset)
preprocessed_test_dataset = preprocessDataset(test_dataset)

# %% [markdown]
# ### Visualize the Data
# - DistPlot and BoxPlot for each feature, looking for visual patterns and outliers

# %%
def visualizeData(data):
    # Data Description
    display(data.head(5))
    display(data.describe())
    
    # Cut (quality of the cut)
    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
    sns.boxplot(data.loc[:, 'cut'], ax=ax_box) 
    sns.distplot(data.loc[:, 'cut'], ax=ax_hist)
    ax_box.set(xlabel='')
    plt.show()
    
    # Color (worse 1-8 good)
    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
    sns.boxplot(data.loc[:, 'color'], ax=ax_box) 
    sns.distplot(data.loc[:, 'color'], ax=ax_hist)
    ax_box.set(xlabel='')
    plt.show()
    
    # Clarity (worse 1-8 good)
    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
    sns.boxplot(data.loc[:, 'clarity'], ax=ax_box) 
    sns.distplot(data.loc[:, 'clarity'], ax=ax_hist)
    ax_box.set(xlabel='')
    plt.show()
    
    # x, y, z (dimensions in mm)
    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.3, .7)})
    sns.boxplot(data=data.loc[:, ['x','y','z']], orient = "h", ax=ax_box) 
    sns.distplot(data.loc[:, 'x'], ax=ax_hist)
    sns.distplot(data.loc[:, 'y'], ax=ax_hist)
    sns.distplot(data.loc[:, 'z'], ax=ax_hist)
    ax_box.set(xlabel='')
    plt.show()
        # Since there are outliers - dimension too small (less than 2mm) or too big (more than 30mm) - they are removed:
    data.drop(data[data.x < 2].index, inplace=True)
    data.drop(data[data.x > 30].index, inplace=True)
    data.drop(data[data.y < 2].index, inplace=True)
    data.drop(data[data.y > 30].index, inplace=True)
    data.drop(data[data.z < 2].index, inplace=True)
    data.drop(data[data.z > 30].index, inplace=True)
        # Plotting the clean data:
    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
    sns.boxplot(data=data.loc[:, ['x','y','z']], orient = "h", ax=ax_box) 
    sns.distplot(data.loc[:, 'x'], ax=ax_hist)
    sns.distplot(data.loc[:, 'y'], ax=ax_hist)
    sns.distplot(data.loc[:, 'z'], ax=ax_hist)
    ax_box.set(xlabel='')
    plt.show()
        # Now we are able to see that the dimensions x and y have tha same shape of distribution, and therefore probably 
        # refers to the dimensions of the sides, while z is confirmed to be the depth of the diamond!
    # Create feature Volume:
    data['volume']=data.x*data.y*data.z
    data['density']=data.carat/data.volume
        
    # Depth:  total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43–79)
    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
    sns.boxplot(data.loc[:, 'depth'], ax=ax_box) 
    sns.distplot(data.loc[:, 'depth'], ax=ax_hist)
    ax_box.set(xlabel='')
    plt.show()
        # We can confirm the values for "depth", making a new variable with the described calculation:
    data['calculated_depth'] = 100*2*data.z/(data.x+data.y)
        # And check if there is any difference from the original values:
    data['discrepancy_in_depth'] = data['calculated_depth']-data['depth'] 
    display(data['discrepancy_in_depth'].describe())
        # \o/ I've found discrepant values! I'll remove those, because we don't know if the error is in x, y or z.
        # The stablished threshold is 1% of discrepancy:
    data.drop(data[data.discrepancy_in_depth.abs() > 1].index, inplace=True)
    display(data['discrepancy_in_depth'].describe())
    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
    sns.boxplot(data.loc[:, 'depth'], ax=ax_box) 
    sns.distplot(data.loc[:, 'depth'], ax=ax_hist)
    ax_box.set(xlabel='')
    plt.show()
    
    # table (width of top of diamond relative to widest point, in percentage)
    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
    sns.boxplot(data.loc[:, 'table'], ax=ax_box) 
    sns.distplot(data.loc[:, 'table'], ax=ax_hist)
    ax_box.set(xlabel='')
    plt.show()
        # There is a diamond with 95% of table. That is very unlikely because of geometry issues. It will be removed.
    data.drop(data[data.table > 90].index, inplace=True)
        # I think there might me some relationship between the table and its depth, so I'll create another feature:
    data['table_by_depth'] = data.table/data.depth    
    display(data.describe())
    
    # Carat (weight of the diamond)
    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
    sns.boxplot(data.loc[:, 'carat'], ax=ax_box) 
    sns.distplot(data.loc[:, 'carat'], ax=ax_hist)
    ax_box.set(xlabel='')
    plt.show()
        # There are values much grater than  the upper limit (Q3 + 1.5*IQR),  
        # but there is a possibility that they are good data. 
        # To ensure that, we are going to check if its density is near the average density of the dataset.
        # For that, we need to create a "density" feature: carat/(x*y*z): 
           
    
    # Correlation:
    correlation_matrix = data.corr()
    correlation_scatter = pd.plotting.scatter_matrix(correlation_matrix, figsize=(12,12))
    plt.show()
    display(correlation_matrix.round(2).style.background_gradient())

visualizeData(preprocessed_train_and_validation_dataset)
visualizeData(preprocessed_test_dataset) # nao posso alterar os dados de teste hahaha, precisa tirar isso daqui
# Out:
#    carat  cut  color  clarity    x    y    z  depth  table  price
# 0   1.62   11      2        4 7.53 7.58 4.69  62.10  55.00  10501
# 1   0.30    7      4        3 4.39 4.35 2.57  58.80  60.00    574
# 2   1.37   11      5        5 7.28 7.22 4.32  59.60  57.00  11649
# 3   0.33    1      3        6 4.40 4.32 2.84  65.10  59.00    922
# 4   0.32    4      5        4 4.43 4.48 2.62  58.80  62.00    602
#          carat      cut    color  clarity        x        y        z    depth  \
# count 45849.00 45849.00 45849.00 45849.00 45849.00 45849.00 45849.00 45849.00
# mean      0.80     7.29     4.41     4.05     5.73     5.73     3.54    61.74
# std       0.47     3.42     1.70     1.64     1.12     1.14     0.69     1.43
# min       0.20     1.00     1.00     1.00     0.00     0.00     0.00    43.00
# 25%       0.40     4.00     3.00     3.00     4.71     4.72     2.91    61.00
# 50%       0.70     7.00     4.00     4.00     5.70     5.71     3.52    61.80
# ...

# %% [markdown]
# ### Find and Remove Outliers

# %%
print('Mean: '), display(preprocessed_train_and_validation_dataset.mean())
print('Standard Deviation: '), display(preprocessed_train_and_validation_dataset.std())
# Out:
# Mean:
# carat                     0.80
# cut                       7.30
# color                     4.41
# clarity                   4.05
# x                         5.73
# y                         5.73
# z                         3.54
# depth                    61.75
# table                    57.45
# price                  3927.50
# volume                  129.72
# density                   0.01
# calculated_depth         61.75
# discrepancy_in_depth      0.00
# table_by_depth            0.93
# dtype: float64
# Standard Deviation:
# carat                     0.47
# cut                       3.42
# color                     1.70
# clarity                   1.64
# x                         1.12
# y                         1.11
# z                         0.69
# depth                     1.42
# table                     2.23
# price                  3985.55
# volume                   76.42
# density                   0.00
# calculated_depth          1.42
# ...

# %%
np.where(preprocessed_train_and_validation_dataset['carat'] > preprocessed_train_and_validation_dataset['carat'].mean() + 4*preprocessed_train_and_validation_dataset['carat'].std())
# Out:
# (array([  547,  1178,  1325,  2454,  2703,  7985,  9177,  9732, 10594,
#         11118, 12274, 12536, 12537, 13635, 14155, 15240, 15489, 15629,
#         16769, 18062, 18581, 20325, 20436, 20889, 23642, 24865, 25418,
#         27121, 27135, 29013, 29483, 30865, 31171, 32208, 34441, 36702,
#         36703, 37572, 38157, 38985, 39840, 40167, 40344, 41307, 42893,
#         43373]),)

# %%
preprocessed_train_and_validation_dataset.iloc[548]
# Out:
# carat                    0.41
# cut                      2.00
# color                    6.00
# clarity                  3.00
# x                        4.73
# y                        4.75
# z                        3.01
# depth                   63.50
# table                   55.00
# price                  654.00
# volume                  67.63
# density                  0.01
# calculated_depth        63.50
# discrepancy_in_depth     0.00
# table_by_depth           0.87
# Name: 549, dtype: float64

# %% [markdown]
# ### Split original "train" dataset onto 80% train and 20% validation

# %%
preprocessed_train_dataset, preprocessed_validation_dataset = train_test_split(preprocessed_train_and_validation_dataset, train_size=0.8, test_size=0.2)
#train_dataset.head()
#alidation_dataset.head()

# %% [markdown]
# ### Scale Dataset
# - Scale dataset based on the training part
# - Scale the validation dataset using the same scale factors

# %%
scaler = preprocessing.StandardScaler()
scaler.fit(preprocessed_train_dataset)
scaled_train_dataset = pd.DataFrame(scaler.transform(preprocessed_train_dataset), columns=preprocessed_train_dataset.columns)
scaled_validation_dataset = pd.DataFrame(scaler.transform(preprocessed_validation_dataset), columns=preprocessed_validation_dataset.columns)
#scaled_train_dataset.head()
#scaled_validation_dataset.head()

# %% [markdown]
# ### Fit a Linear Model
# - Split datasets into inputs and output
# - Prepend x0 = 1 (intercept constant)
# - Create a linear regression model
# - Fit it to the training data

# %%
X_train = scaled_train_dataset.drop(columns=['price'])
X_train.insert(0,' x0',1)
Y_train = scaled_train_dataset['price']
X_val = scaled_validation_dataset.drop(columns=['price'])
X_val.insert(0,' x0',1)
Y_val = scaled_validation_dataset['price']

lin_reg = linear_model.LinearRegression()
lin_reg = lin_reg.fit(X_train, Y_train)

# %% [markdown]
# ### Predict using the Model
# - Predict using the scaled validation input
# - Analyse the accuracy of the prediction
# - Apply the inverse scaler to the prediction

# %%
Y_predicted_scaled = lin_reg.predict(X_val)
Score = lin_reg.score(X_val, Y_val)
Score
# Out:
# 0.9088887042350277

# %% [markdown]
# ### Analyze accuracy of the model
# - plot?
# - Cost function?
